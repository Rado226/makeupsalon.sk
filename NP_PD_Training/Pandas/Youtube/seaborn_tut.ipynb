# %%
import numpy as np
import pandas as pd
import seaborn as sns 

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Tutorial na použitie seaborn

# %%
tips = sns.load_dataset("tips")
tips
titanic = sns.load_dataset("titanic")

# %% [markdown]
# 1. Vytvorenie scatterplot

# %%
sns.scatterplot(x="tip", y="total_bill", data=tips, hue="sex", size="size") #palette
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# 2. Histogram

# %%
sns.histplot(tips["tip"], kde=True, bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# 3. Bar plot

# %%
sns.barplot(x ="sex", y ="tip", data = tips, palette="bright")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9008\3971768254.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x ="sex", y ="tip", data = tips, palette="bright")
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# 4. Box plot

# %%
sns.boxplot(x="day", y="tip",data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 5. Stripplot

# %%
sns.stripplot(x="day", y="tip",data = tips, hue="sex", palette="bright", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 6. Join plot

# %%
sns.jointplot(x="tip", y = "total_bill", data=tips, kind="reg")

# %%
sns.jointplot(x="tip", y = "total_bill", data=tips, kind="hex")

# %%
sns.jointplot(x="tip", y = "total_bill", data=tips, kind="kde",shade =True)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %% [markdown]
# 7. Pair Plot

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
sns.pairplot(titanic.select_dtypes(["number"]),hue = "pclass")

# %% [markdown]
# 8. Heatmap

# %%
num_titanic = titanic.select_dtypes(include=["number"])
sns.heatmap(num_titanic, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >
